# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('./Журнал активных вызовов 01-2020.xls', skiprows = 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10119 entries, 0 to 10118
# Data columns (total 21 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  9599 non-null   object
#  1   Unnamed: 1                                    5592 non-null   object
#  2   Unnamed: 2                                    1597 non-null   object
#  3   Unnamed: 3                                    1705 non-null   object
#  4   Unnamed: 4                                    1597 non-null   object
#  5   Unnamed: 5                                    1 non-null      object
#  6   Unnamed: 6                                    0 non-null      float64
#  7   Unnamed: 7                                    1597 non-null   object
#  8   Unnamed: 8                                    1704 non-null   datetime64[ns]
# ...

# %%
df[0:+6]
# Out:
#   С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 0                          2020-01-01 00:00:00
# 1                                       Адрес:
# 2                                       Повод:
# 3                                     Диагноз:
# 4                                   Доставлен:
# 5                                      Принят:
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN     Номер:       8(8)
# 1                                                NaN        NaN        NaN
# 2                              Температура, взрослый        NaN        NaN
# 3                     ОРВИ. Гипертермический синдром        NaN        NaN
# 4  ГБУЗ НО "Городская поликлиника №7" (ул. Верхне...        NaN        NaN
# 5                                                NaN        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[6:6+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 6                           2020-01-01 00:00:00
# 7                                        Адрес:
# 8                                        Повод:
# 9                                      Диагноз:
# 10                                   Доставлен:
# 11                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 6                                                 NaN     Номер:     16(16)
# 7         г.Нижний Новгород, ш. Казанское, д.9, кв***        NaN        NaN
# 8                              Болит живот (взрослый)        NaN        NaN
# 9                                           Люмбалгия        NaN        NaN
# 10  ГБУЗ НО "Городская поликлиника №7" (ул. Верхне...        NaN        NaN
# 11                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[12:12+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 12                          2020-01-01 00:00:00
# 13                                       Адрес:
# 14                                       Повод:
# 15                                     Диагноз:
# 16                                   Доставлен:
# 17                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 12                                                NaN     Номер:     21(21)
# 13  г.Нижний Новгород, ул. Родионова, д.167, корп....        NaN        NaN
# 14                                                NaN        NaN        NaN
# 15                                     Острый бронхит        NaN        NaN
# 16  ГБУЗ НО "Детская городская поликлиника №22" (у...        NaN        NaN
# 17                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[18:18+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 18                          2020-01-01 00:00:00
# 19                                       Адрес:
# 20                                       Повод:
# 21                                     Диагноз:
# 22                                   Доставлен:
# 23                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 18                                                NaN     Номер:     28(28)
# 19                                                NaN        NaN        NaN
# 20                              Болит живот (ребенок)        NaN        NaN
# 21                Другие болезни желчевыводящих путей        NaN        NaN
# 22  ГБУЗ НО "Детская городская поликлиника №22" (у...        NaN        NaN
# 23                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[24:24+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 24                          2020-01-01 00:00:00
# 25                                       Адрес:
# 26                                       Повод:
# 27                                     Диагноз:
# 28                                   Доставлен:
# 29                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 24                                                NaN     Номер:     29(29)
# 25    г.Нижний Новгород, ул. Богдановича, д.1, кв.***        NaN        NaN
# 26                             Болит живот (взрослый)        NaN        NaN
# 27                                            Гастрит        NaN        NaN
# 28  ГБУЗ НО "Городская поликлиника №7" (ул. Верхне...        NaN        NaN
# 29                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[30:30+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 30                          2020-01-01 00:00:00
# 31                                       Адрес:
# 32                                       Повод:
# 33                                     Диагноз:
# 34                                   Доставлен:
# 35                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 30                                                NaN     Номер:     51(51)
# 31       г.Нижний Новгород, ул. Ванеева, д.108, кв***        NaN        NaN
# 32                                                NaN        NaN        NaN
# 33                                  Кишечная инфекция        NaN        NaN
# 34  ГБУЗ НО "Детская городская поликлиника №48" (у...        NaN        NaN
# 35                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[36:36+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 36                          2020-01-01 00:00:00
# 37                                       Адрес:
# 38                                       Повод:
# 39                                     Диагноз:
# 40                                   Доставлен:
# 41                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 36                                                NaN     Номер:     52(52)
# 37     г.Нижний Новгород, ул. Героя Быкова, д.9, к***        NaN        NaN
# 38  Температура 38-39, ребёнок >1 года, других жал...        NaN        NaN
# 39                     ОРВИ. Гипертермический синдром        NaN        NaN
# 40  ГБУЗ НО "Детская городская поликлиника №48" (у...        NaN        NaN
# 41                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[42:42+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 42                          2020-01-01 00:00:00
# 43                                       Адрес:
# 44                                       Повод:
# 45                                     Диагноз:
# 46                                   Доставлен:
# 47                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 42                                                NaN     Номер:     66(66)
# 43                                                NaN        NaN        NaN
# 44                                  Констатация, умер        NaN        NaN
# 45                                                NaN        NaN        NaN
# 46  ГБУЗ НО "Городская поликлиника №30" (ул. Адмир...        NaN        NaN
# 47                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[48:48+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 48                          2020-01-01 00:00:00
# 49                                       Адрес:
# 50                                       Повод:
# 51                                     Диагноз:
# 52                                   Доставлен:
# 53                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 48                                                NaN     Номер:     69(69)
# 49                                                NaN        NaN        NaN
# 50                              Температура, взрослый        NaN        NaN
# 51                     ОРВИ. Гипертермический синдром        NaN        NaN
# 52  ГБУЗ НО "Городская клиническая больница №34" П...        NaN        NaN
# 53                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[54:54+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 54                          2020-01-01 00:00:00
# 55                                       Адрес:
# 56                                       Повод:
# 57                                     Диагноз:
# 58                                   Доставлен:
# 59                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 54                                                NaN     Номер:     77(77)
# 55                                                NaN        NaN        NaN
# 56                              Температура, взрослый        NaN        NaN
# 57                     ОРВИ. Гипертермический синдром        NaN        NaN
# 58  ГБУЗ НО "Детская городская поликлиника №48" (у...        NaN        NaN
# 59                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[60:60+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 60                          2020-01-01 00:00:00
# 61                                       Адрес:
# 62                                       Повод:
# 63                                     Диагноз:
# 64                                   Доставлен:
# 65                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 60                                                NaN     Номер:     87(87)
# 61                                                NaN        NaN        NaN
# 62          Высокое ад, головная боль, тошнота, рвота        NaN        NaN
# 63     Гипертоническая болезнь. Гипертонический криз.        NaN        NaN
# 64  ГБУЗ НО "Городская поликлиника №7" (ул. Турген...        NaN        NaN
# 65                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
Первый блок длиной 5 строк ниже

# %%
df[66:66+5]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 66                          2020-01-01 00:00:00
# 67                                          NaN
# 68                                          NaN
# 69                                          NaN
# 70                                          NaN
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 66                                                NaN        NaN     87(87)
# 67          Высокое ад, головная боль, тошнота, рвота        NaN        NaN
# 68     Гипертоническая болезнь. Гипертонический криз.        NaN        NaN
# 69  ГБУЗ НО "Городская поликлиника №7" (ул. Турген...        NaN        NaN
# 70                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# 66        NaN        NaN         NaN        NaN                     NaT
# ...

# %%
df[71:71+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 71                          2020-01-01 00:00:00
# 72                                       Адрес:
# 73                                       Повод:
# 74                                     Диагноз:
# 75                                   Доставлен:
# 76                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 71                                                NaN     Номер:     92(92)
# 72                                                NaN        NaN        NaN
# 73     Температура, ребенок >1 года, других жалоб нет        NaN        NaN
# 74                     ОРВИ. Гипертермический синдром        NaN        NaN
# 75  ГБУЗ НО "Детская городская поликлиника №22" (у...        NaN        NaN
# 76                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
df[77:77+6]
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 77                          2020-01-02 00:00:00
# 78                                       Адрес:
# 79                                       Повод:
# 80                                     Диагноз:
# 81                                   Доставлен:
# 82                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 77                                                NaN     Номер:   104(104)
# 78                                                NaN        NaN        NaN
# 79                              Температура, взрослый        NaN        NaN
# 80                     ОРВИ. Гипертермический синдром        NaN        NaN
# 81  ГБУЗ НО "Детская городская поликлиника №22" (у...        NaN        NaN
# 82                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
# for i, row in df.iterrows():
#     print(row[3]) # номер
#     break
# Out:
# 8(8)

# %%
df[0:+6].iloc[0,3]  # Номер
# Out:
# '8(8)'

# %%
df[6:6+6].iloc[0,3] # Номер
# Out:
# '16(16)'

# %%
df[60:60+6].iloc[0,3] # Номер
# Out:
# '87(87)'

# %%
df[66:66+6].iloc[0,3] # Если номер такой же то пересчитыем индексы блока
# Out:
# '87(87)'

# %%
df[71:71+6].iloc[0,3] # Новый блок # Номер
# Out:
# '92(92)'

# %%
df[77:77+6].iloc[0,3] # Номер
# Out:
# '104(104)'

# %%
df[77:77+6] # All
# Out:
#    С 01.01.2020 07:00:00 по 31.01.2020 23:59:00  \
# 77                          2020-01-02 00:00:00
# 78                                       Адрес:
# 79                                       Повод:
# 80                                     Диагноз:
# 81                                   Доставлен:
# 82                                      Принят:
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 77                                                NaN     Номер:   104(104)
# 78                                                NaN        NaN        NaN
# 79                              Температура, взрослый        NaN        NaN
# 80                     ОРВИ. Гипертермический синдром        NaN        NaN
# 81  ГБУЗ НО "Детская городская поликлиника №22" (у...        NaN        NaN
# 82                                                NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7              Unnamed: 8  \
# ...

# %%
s = 77
e = 77+6

df[s:e].iloc[0,0] # Дата
df[s:e].iloc[1,1] # Адрес
df[s:e].iloc[0,3] # Номер
df[s:e].iloc[0,16] # Возраст
df[s:e].iloc[0,19] # Поле после возраста
df[s:e].iloc[2,1] # Повод
df[s:e].iloc[3,1] # Диагноз
df[s:e].iloc[4,1] # Доставлен
df[s:e].iloc[5,8] # Принят # Timestamp
df[s:e].iloc[5,11] # Приезд # datetime.datetime
df[s:e].iloc[2,11] # Вызов 
df[s:e].iloc[2,18] # Вид
df[s:e].iloc[3,11] # Результа
# Бригада  Пустой?
df[s:e].iloc[4,17] # Подстанция
# Госпитализирован  Пустой?
#  Испол. Пустой?
# Больной Пустой?
# Out:
# 'ПСМП №7'

# %%
s = 0
e = 6
df[s:e+6].iloc[0,0], df[s:e].iloc[1,1], df[s:e].iloc[0,3], df[s:e].iloc[0,16], df[s:e].iloc[0,19], df[s:e].iloc[2,1], df[s:e].iloc[3,1],df[s:e].iloc[4,1], df[s:e].iloc[5,8], df[s:e].iloc[5,11], df[s:e].iloc[2,11], df[s:e].iloc[2,18], df[s:e].iloc[3,11], df[s:e].iloc[4,17]
# Out:
# (datetime.datetime(2020, 1, 1, 0, 0),
#  nan,
#  '8(8)',
#  '26 лет',
#  'родственник, проживающий совместно с больным',
#  'Температура, взрослый',
#  'ОРВИ. Гипертермический синдром',
#  'ГБУЗ НО "Городская поликлиника №7" (ул. Верхне-Печерская).',
#  Timestamp('1970-01-01 09:46:15.281000'),
#  datetime.datetime(1970, 1, 1, 9, 52, 22, 890000),
#  'Первичный',
#  'неотложное состояние',
#  'оказана помощь, больной оставлен на месте',
#  'ПСМП №7')

# %% [markdown]
# Последний блок обрезан по строкам (4 вместо 6)  в 01-2022
